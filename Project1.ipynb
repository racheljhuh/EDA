# %% [markdown]
# Summary:
#
# Variable 1 - HAPPY = General Happiness
#
# Variable 2 - HEALTH = Health Status
#
# Variable 3 - PRESTG10 = prestige of occupation (scale 0-100)

# %%
#Data
import numpy as np # Import the numpy package into your workspace
import pandas as pd  # Import the pandas package into your workspace
import seaborn as sns # Import Seaborn
import matplotlib.pyplot as plt

# %%
! git clone https://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@github.com/DS3001/group3.git
df = pd.read_csv('./group3/smalldf_notcleaned.csv',low_memory=False)
df = df[df['year'] == 2022]
df.head() #filter the data to only include 2022 data
# Out:
# fatal: destination path 'group3' already exists and is not an empty directory.
#        year  id          happy health        marital  prestg10  prestg105plus
# 68846  2022   1  not too happy   good       divorced      39.0            NaN
# 68847  2022   2  not too happy   good        married      53.0            NaN
# 68848  2022   3  not too happy   good       divorced      48.0            NaN
# 68849  2022   4  not too happy   good  never married      34.0            NaN
# 68850  2022   5   pretty happy   fair  never married      38.0            NaN

# %% [markdown]
# Results:

# %%
hi

# %% [markdown]
# Conclusion:

# %% [markdown]
# Appendix:
